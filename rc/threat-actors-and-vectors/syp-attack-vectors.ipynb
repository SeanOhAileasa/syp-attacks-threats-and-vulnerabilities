# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/syp-attacks-threats-and-vulnerabilities/blob/main/README.md) >
#
# ## CompTIA Security+ - Course Material 2022
# ###### Topic: ``Attack Vectors``
# ***

# %% [markdown]
# Course material for the ``CompTIA Security+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [Attack Vectors](#a) <br/><br/>
#
# - [Direct Access](#b) <br/><br/>
# - [Modify OS](#c) <br/><br/>
# - [Keylogger](#d) <br/><br/>
# - [Portable Media](#e) <br/><br/>
# - [Physical Access](#f) <br/><br/>
#     - [DoS](#f) <br/><br/>
# - [Wireless Attack Vectors](#g) <br/><br/>
#     - [Default Login Credentials](#h) <br/><br/>
#     - [Rogue Access Point](#i) <br/><br/>
#     - [Evil Twin](#j) <br/><br/>
#     - [Protocol Vulnerabilities](#k) <br/><br/>
#         - [WPA](#l) <br/><br/>
#             - [KRACK](#l) <br/><br/>
#         - [WEP - WPA](#m) ``WPA2`` <br/><br/>
# - [Email](#n) <br/><br/>
# - [Supply Chain](#o) <br/><br/>
#     - [2013 - Target](#p) <br/><br/>
#     - [2010 - Stuxnet Worm](#q) <br/><br/>
#     - [2020 - Cisco Switches](#r) <br/><br/>
#         - [``Catalyst 2960-X``](#r) <br/><br/>
#         - [``WS-2960X-48TS-L``](#r) <br/><br/>
# - [Social Media](#s) <br/><br/>
# - [Removable Media](#t) <br/><br/>
# - [Cloud-based Applications](#u) <br/><br/>
#     - [Security Misconfigurations](#u) <br/><br/>
#     - [Brute Force or Phish](#v) <br/><br/>
#     - [Waste Resources](#w) <br/><br/>
#     - [DoS](#x)
# <hr width=50%;>

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="a"></a>
# ***
# ### Attack Vectors
# ***

# %% [markdown]
# The attack vector is the method that the attacker will use to gain access to your computer or your network - they are trying to find all of the different ways that they could somehow get around the existing security and find their way to the inside of your network.
#
# Attackers spend a lot of time trying to find these vulnerabilities - all they need is that one single vulnerability, and they’ve now gained access to the target.
#
# As a security professional, will spend a lot of time watching these attack vectors - going to be patching a lot of systems to close existing vulnerabilities, and of course watching to see if someone takes advantage of other attack vectors that simply have not yet been discovered.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="b"></a>
# ***
# ###### Direct Access
# ***

# %% [markdown]
# If an attacker has direct access to the hardware that is running an operating system, then they have a lot of attack vectors available to them - they will find a way into that operating system if they have physical access - this is one of the reasons why all of our data centers are locked up and are usually very highly secured.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="c"></a>
# ***
# ###### Modify OS
# ***

# %% [markdown]
# With many operating systems, you can reboot the system into a particular administrative mode, make a change to an administrative password, reboot again, and now you have full access to the operating system and although that’s a very common attack vector, there are ways to prevent someone from gaining this type of access to the system, but it’s very difficult to do if they have direct access to that piece of equipment.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="d"></a>
# ***
# ###### Keylogger
# ***

# %% [markdown]
# A common direct access attack vector is to attach a keylogger to a keyboard. The keyboards are usually directly on these servers, and the administrators are walking up to the systems and typing in their usernames and passwords.
#
# The attackers will put a keylogger into the keyboard system, so they’ll simply disconnect the keyboard and put that right in the middle - can see it’s very small - may not even realize that it’s connected to your computer.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# That keylogger will remain on that system for a certain amount of time, and then the attacker will stop back by, remove the keylogger, and then take it somewhere else to see exactly what everyone typed into that keyboard while that keylogger was attached.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="e"></a>
# ***
# ###### Portable Media
# ***

# %% [markdown]
# Another direct access vector is one where you can simply connect a flash drive or some other type of portable media and just simply copy all of the files from that server onto a piece of media that you can then take outside the building with you.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="f"></a>
# ***
# ###### Physical Access - DoS
# ***

# %% [markdown]
# Of course, if someone has physical access to the computer, they can simply pull the power cord, pour water into the system, and create a denial-of-service.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="g"></a>
# ***
# ###### Wireless Attack Vectors
# ***

# %% [markdown]
# On wireless networks, there are a number of attack vectors you have to be aware of.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="h"></a>
# ***
# ###### Default Login Credentials
# ***

# %% [markdown]
# Have to make sure that your access point is secure - usually these have usernames and passwords to authenticate the administrator into the system, and you want to be sure you’re not using the default credentials, which of course will be very easy for an attacker to use.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="i"></a>
# ***
# ###### Rogue Access Point
# ***

# %% [markdown]
# Also have to make sure that your network is not designed to allow rogue access points - this would be someone who brings in an unauthorized wireless access point and plugs it in - if one of your end users is able to do that, then they can effectively turn on a wide open access point that anyone would be able to connect to.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="j"></a>
# ***
# ###### Evil Twin
# ***

# %% [markdown]
# A more malicious form of a rogue access point is an evil twin.
#
# An evil twin is specifically designed to be a hacking tool, and it’s made to emulate or look very similar to the access points that are already on your network - this evil twin is designed to fool your users and get them to connect to the evil twin access point instead of the legitimate corporate access point.
#
# Once your users are sending data to this malicious access point, the attacker is able to see all of the data going by and even change that data by using an on-path attack.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="k"></a>
# ***
# ###### Protocol Vulnerabilities
# ***

# %% [markdown]
# Also have to make sure that your access points and your clients are using the latest technologies.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="l"></a>
# ***
# ###### WPA - KRACK
# ***

# %% [markdown]
# In 2017, a vulnerability was found with many clients that used ``WPA2``, and they found a key reinstallation attack called [ [KRACK](https://www.krackattacks.com/) ] that would be able to gain access to WPA2 networks.
#
# This is a vulnerability that was very quickly resolved by updating most of the wireless clients.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="m"></a>
# ***
# ###### WEP - WPA - ``WPA2``
# ***

# %% [markdown]
# There are also some older encryption technologies that have significant vulnerabilities, technologies like WEP and WPA, so you want to be sure that you’re running ``WPA2`` or later on your wireless access points.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="n"></a>
# ***
# ###### Email
# ***

# %% [markdown]
# Email has traditionally been a very successful attack vector for threat actors, and that’s because so many people have an email account. The attackers can send phishing links through email and gather personal information directly from the end user, or they may be attaching malware or other malicious software to the email and having people launch that software from their email client.
#
# This is also a great place to perform social engineering attacks, like sending in a fake invoice and convincing people to pay a bill that is not legitimate - this is one of the largest and most difficult attack vectors to manage, and if you’re someone working in IT, you’re probably very focused on keeping all of your email messages as secure as possible.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="o"></a>
# ***
# ###### Supply Chain
# ***

# %% [markdown]
# It’s very likely that most of the things in your organization were purchased from a third party - there’s an entire supply chain designed to provide you with these products, and many different manufacturers and entities were connected with that supply chain until it reached you.
#
# Each one of those steps along the way is an attack vector, so it’s important that you know exactly where your technology comes from and that it is as safe as possible.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="p"></a>
# ***
# ###### 2013 - Target
# ***

# %% [markdown]
# In the 2013 credit card breach from Target, the attackers took advantage of the supply chain to gain access to the Target network - those attackers used a third party to Target - this was one of Target’s vendors that then had access to the internal Target network and once the attacker was able to gain access inside of the Target network, they effectively had access to all of the cash registers at every Target location.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="q"></a>
# ***
# ###### Stuxnet Worm
# ***

# %% [markdown]
# A good example of using the supply chain to disrupt a manufacturing process was in 2010 with the Stuxnet worm - this was a partnership between the United States and Israel that put a worm into Iran’s uranium enrichment program and disrupted the centrifuges that were used during that manufacturing.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="r"></a>
# ***
# ###### 2020 - Cisco Switches - ``Catalyst 2960-X`` - ``WS-2960X-48TS-L``
# ***

# %% [markdown]
# In 2020, network administrators started to notice that their Cisco switches weren’t exactly what they were expecting - there were at least two models of Cisco switches that did not originate at Cisco.
#
# The details of where these switches came from and what the purpose of having these fake switches might have been is still a bit of a mystery, but it certainly speaks to how important it is to be very secure with your supply chain.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="s"></a>
# ***
# ###### Social Media
# ***

# %% [markdown]
# Attackers can gather a lot of information from social media, and sometimes it’s too much information - just by watching someone’s timeline, they may be able to determine where you are and when you may have visited a location, or they might see that you’re on vacation for two weeks, and you’re going to be nowhere near your home.
#
# These social media attack vectors could also be used to attack multifactor authentication - they might be able to look at your social media account and know where you were born or when you were born, or they might know the name of your school mascot based on your Facebook profile - this information can then be used during a password reset that would then allow the attacker access to your account.
#
# There’s more than one example where someone was pretending to be a friend to gain access to your social media account, and so you have to be very careful about who you allow access to your data and who is kept on the outside and away from your personal information.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="t"></a>
# ***
# ###### Removable Media
# ***

# %% [markdown]
# One way to gain access to data that may not normally be accessible is to find ways around the existing security technologies.
#
# One way to do this is to get on the inside and connect up a system that would allow you to transfer data out of an organization - this can be very easy with a USB drive, and attackers use USB connections constantly to be able to gather information and circumvent existing security controls.
#
# This type of attack may be required if a particular area of a network isn’t connected to the internet - it may be air gapped, and there may be no direct connection to be able to communicate with it but if you can somehow plug in an infected USB drive, you may be able to infect the system and then have it communicate out to the attacker.
#
# May have a USB device that looks just like a flash drive, but in reality, it looks and acts as if it’s a keyboard, so the instant you plug it in, it will start typing on your computer as if it was a person on a keyboard - this is effectively a hacker that’s on a chip inside of this USB-connected device, and it makes it very easy for the attacker to gain access to your systems.
#
# Of course, the storage capabilities of these flash drives are getting much larger, while the flash drives and devices continue to get smaller - this makes it very easy to plug in, transfer a bunch of data, disconnect, and then hide that data as you walk outside the building and exfiltrate everything that may have been on the inside.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="u"></a>
# ***
# ###### Cloud-based Applications - Security Misconfigurations
# ***

# %% [markdown]
# Cloud-based applications have brought an entirely new set of attack vectors to consider.
#
# Very often, these applications are publicly-facing, so it’s not only important that the application is secure, but the entire configuration of that application, for example, if you’re putting data in the cloud, you want to be sure that data is protected from prying eyes - the application should be the only thing gaining access to that data, but unfortunately, misconfigurations can be made, and certain areas of data may be opened up for anyone to be able to see.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="v"></a>
# ***
# ###### Brute Force or Phish
# ***

# %% [markdown]
# Attackers are usually very good at brute forcing access to these publicly-facing applications, but they might also use phishing techniques to have users send them their own usernames and passwords.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="w"></a>
# ***
# ###### Waste Resources
# ***

# %% [markdown]
# Attackers might also have you waste resources by increasing the load on a particular cloud-based service and requiring additional instances of that application to be created - this may not allow the attacker access to your data, but it would certainly cost resources and money.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="x"></a>
# ***
# ###### DoS
# ***

# %% [markdown]
# Given these applications are public-facing, it’s important that you plan for any denial-of-service - anyone would be able to access that device from the outside, so you want to be sure you have all of the security tools in place to mitigate or prevent any type of denial-of-service attack.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# J. "Professor" Messer, "CompTIA Security+ (SY0-601) Course Notes," [professormesser.com](https://web.archive.org/web/20220521181010/https://www.professormesser.com/security-plus/sy0-601/sy0-601-video/sy0-601-comptia-security-plus-course/), September 2021.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
